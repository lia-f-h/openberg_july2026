# %% [markdown]
# # Analysis of simulated trajectorories

# %%
cd ~/work/tutorials/sources/OpenDrift/openberg_july2026
# Out:
# /home/jovyan/work/tutorials/sources/OpenDrift/openberg_july2026

# %%
# import pandas as pd
# import xarray as xr
# import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
import glob
from src.utils import *
from openberg_july2026.src2.utils2 import *
from openberg_july2026.src2.utils3 import *

# %%
ib = 'iceberg2018b'

# %%
#read sim
file_contain_all = [ib,]
file_contain_any = ['_']
file_notcontain = ['test','idx']#'test','wa','next','glorys']#['topaz4','glorys','slope','era5','almost','stokes',]
file_l = glob.glob("./results/*.nc")#['./results/juliette_topaz6_topaz4_windglophynrt.nc',]
file_l = [f for f in file_l if all(ff in f for ff in file_contain_all)] #filtering for required keywords
file_l = [f for f in file_l if any(ff in f for ff in file_contain_any)] #filtering for required keywords
file_l = [f for f in file_l if all(ff not in f for ff in file_notcontain)] #filtering for neglected keywords
file_l = file_l[::-1]
print(file_l)
# Out:
# ['./results/iceberg2018b_gebco_topaz6_topaz4_windglophyre_joined.nc', './results/iceberg2018b_gebco_glorys_windglophyre_joined.nc', './results/iceberg2018b_gebco_topaz4_windglophyre.nc']

# %%
#checks
for f in file_l:
    sim=xr.open_dataset(f)
    print(f,sim.trajectory.size,sim.time.size,sim.attrs['config_drift:vertical_profile'],np.all(np.isnan(sim.lat.values)))
# Out:
# ./results/iceberg2018b_gebco_topaz6_topaz4_windglophyre_joined.nc 121 4776 False False
# ./results/iceberg2018b_gebco_glorys_windglophyre_joined.nc 121 4536 False False
# ./results/iceberg2018b_gebco_topaz4_windglophyre.nc 121 4536 False False

# %%
# #Join individual idx files
# fname = 'iceberg2018b_gebco_topaz6_topaz4_windglophyre.nc'
# join_ds_by_idx(file_dict_idx(file_l)[fname]['files'])

# # #if overlap in trajectories: subset, save, rejoin
# # test = xr.open_dataset()
# # test = test.sel(trajectory:np.arange())
# # test.to_netcdf('.nc','w')

# # #test
# test = xr.open_dataset('./results/'+fname.replace('.nc','_joined.nc'))
# print(np.all(np.isnan(sim.lat.values)), test.trajectory.values)
# test.x_sea_water_velocity.plot()

# %%
#dicts and definitions
from openberg_july2026.src2.utils3 import legenddict_full 
legenddict_full = {k:v for k,v in legenddict_full.items() if k!='ICEBERG'}
legenddict = dict.fromkeys([f.split('/')[-1][:-3] for f in file_l])
for f in legenddict:
    ll = []
    for l in legenddict_full:
        if l.lower() in f: ll = ll+[l]
    legenddict[f]={'col':legenddict_full[ll[-1]]['col'], 'alpha':1, 'kw':', '.join(ll),'zo':legenddict_full[ll[-1]]['zo'],
                 # 'traj':np.arange(obs.time.size*11)
                  }

legenddict
# Out:
# {'iceberg2018b_gebco_topaz6_topaz4_windglophyre_joined': {'col': 'turquoise',
#   'alpha': 1,
#   'kw': 'WINDGLOPHYRE, TOPAZ4, TOPAZ6',
#   'zo': 24},
#  'iceberg2018b_gebco_glorys_windglophyre_joined': {'col': 'darkolivegreen',
#   'alpha': 1,
#   'kw': 'WINDGLOPHYRE, GLORYS',
#   'zo': 20},
#  'iceberg2018b_gebco_topaz4_windglophyre': {'col': 'darkslateblue',
#   'alpha': 1,
#   'kw': 'WINDGLOPHYRE, TOPAZ4',
#   'zo': 22}}

# %%
#very simple plot of simulations
# ib = 'iceberg2018b'
apn = None

#read obs
with xr.open_dataset('./input/merged_obs10.nc') as ds:
    obs = ds.sel(iceberg=ib,trajectory_id=ib) 
    #obs = obs.isel(time=(obs.seed_idx==1))

#Figure
fig,ax = plt.subplots(1,1,figsize=(10,10),subplot_kw={'projection':ccrs.NorthPolarStereo(central_longitude=float(obs.lon.mean()))})#central_longitude=20})
ax.coastlines(resolution='10m')
trans = ccrs.PlateCarree()

# # plot obs
ax.plot(obs['lon'].isel(time=(obs.seed_idx==1)),obs['lat'].isel(time=(obs.seed_idx==1)),'>',transform=trans,color='k',label='Seeding points')
ax.plot(obs['lon'],obs['lat'],transform=trans,color='k',label='Observation')
# for d in range(obs_3day['time'].size):
for d in range(obs['time'].isel(time=(obs.seed_idx==1)).size):
#     if d not in [1,2,3,4,5,12,15,16,17,18,19]:
        ax.text(obs['lon'].isel(time=(obs.seed_idx==1))[d],obs['lat'].isel(time=(obs.seed_idx==1))[d],obs['time'].isel(time=(obs.seed_idx==1))[d].values.astype('datetime64[D]').astype(str),transform=trans,color='k',fontsize=12)

# plot sim
for inputdataidx, inputdata in enumerate(file_l[::-1]):
    sim = xr.open_dataset(inputdata)
    inputdata = inputdata.split('/')[-1][:-3]
    if apn!=None: sim = sim.sel(time=dict_analysis_period[ib][apn])
    if ib in dict_traj: 
        if inputdata in dict_traj[ib]: sim = sim.sel(trajectory=dict_traj[ib][inputdata])
    for traj in sim.trajectory:
        ax.plot(sim.lon.sel(trajectory=traj).dropna(dim="time"),sim.lat.sel(trajectory=traj).dropna(dim="time"),
                color=legenddict[inputdata]['col'] if 'prof' not in inputdata else 'red',
                label=(legenddict[inputdata]['kw'] if traj==sim.trajectory[0] else '') if 'mainrun' not in inputdata else '',
                zorder=legenddict[inputdata]['zo'],
            transform=trans)


#legend
h, l = ax.get_legend_handles_labels()
by_label = dict(zip(l, h))
ax.legend(handles=list(by_label.values())[::-1],
         labels=list(by_label.keys())[::-1],
          loc='best')
# plt.legend()
plt.axis('off')
# note = ''
# fig.savefig('./results/%s_map_%s.png'%(iceberg_id,note),dpi=200,transparent=True,bbox_inches='tight')
plt.show()

# %%
sim.attrs
# Out:
# {'Conventions': 'CF-1.11, ACDD-1.3',
#  'standard_name_vocabulary': 'CF Standard Name Table v85',
#  'featureType': 'trajectory',
#  'title': 'OpenDrift trajectory simulation',
#  'summary': 'Output from simulation with OpenDrift framework',
#  'keywords': 'trajectory, drift, lagrangian, simulation',
#  'history': 'Created 2026-08-19 11:13:13.079464',
#  'date_created': '2026-08-19T11:13:13.079472',
#  'source': 'Output from simulation with OpenDrift',
#  'model_url': 'https://github.com/OpenDrift/opendrift',
#  'opendrift_class': 'OpenBerg',
#  'opendrift_module': 'openberg_july2026.src2.openberg_lia',
#  'readers': "odict_keys(['gebco', 'LazyReader: https://thredds.met.no/thredds/dodsC/cmems/topaz6/dataset-topaz6-arc-15min-3km-be.ncml', 'LazyReader: cmems_mod_arc_phy_my_topaz4_P1D-m', 'LazyReader: cmems_obs-wind_glo_phy_my_l4_0.125deg_PT1H'])",
#  'time_coverage_start': '2018-12-11 00:00:08',
#  'time_step_calculation': '1:00:00',
#  'time_step_output': '1:00:00',
#  'config_environment:constant:x_sea_water_velocity': 'None',
#  'config_environment:fallback:x_sea_water_velocity': np.int64(0),
#  'config_environment:constant:y_sea_water_velocity': 'None',
#  'config_environment:fallback:y_sea_water_velocity': np.int64(0),
#  'config_environment:constant:sea_floor_depth_below_sea_level': 'None',
#  'config_environment:fallback:sea_floor_depth_below_sea_level': np.int64(10000),
#  'config_environment:constant:sea_surface_height': 'None',
#  'config_environment:fallback:sea_surface_height': np.int64(0),
#  'config_environment:constant:sea_surface_x_slope': 'None',
#  'config_environment:fallback:sea_surface_x_slope': np.int64(0),
#  'config_environment:constant:sea_surface_y_slope': 'None',
#  'config_environment:fallback:sea_surface_y_slope': np.int64(0),
#  'config_environment:constant:x_wind': 'None',
#  'config_environment:fallback:x_wind': np.int64(0),
#  'config_environment:constant:y_wind': 'None',
#  'config_environment:fallback:y_wind': np.int64(0),
#  'config_environment:constant:horizontal_diffusivity': 'None',
#  'config_environment:fallback:horizontal_diffusivity': np.int64(0),
#  'config_environment:constant:sea_surface_wave_significant_height': 'None',
#  'config_environment:fallback:sea_surface_wave_significant_height': np.int64(0),
#  'config_environment:constant:sea_surface_wave_from_direction': 'None',
#  'config_environment:fallback:sea_surface_wave_from_direction': np.int64(0),
#  'config_environment:constant:sea_surface_wave_stokes_drift_x_velocity': 'None',
#  'config_environment:fallback:sea_surface_wave_stokes_drift_x_velocity': np.int64(0),
#  'config_environment:constant:sea_surface_wave_stokes_drift_y_velocity': 'None',
#  'config_environment:fallback:sea_surface_wave_stokes_drift_y_velocity': np.int64(0),
#  'config_environment:constant:sea_water_temperature': 'None',
#  'config_environment:fallback:sea_water_temperature': np.int64(2),
#  'config_environment:constant:sea_water_salinity': 'None',
#  'config_environment:fallback:sea_water_salinity': np.int64(35),
#  'config_environment:constant:sea_ice_area_fraction': 'None',
#  'config_environment:fallback:sea_ice_area_fraction': np.int64(0),
#  'config_environment:constant:sea_ice_thickness': 'None',
#  'config_environment:fallback:sea_ice_thickness': np.int64(0),
#  'config_environment:constant:sea_ice_x_velocity': 'None',
#  'config_environment:fallback:sea_ice_x_velocity': np.int64(0),
#  'config_environment:constant:sea_ice_y_velocity': 'None',
#  'config_environment:fallback:sea_ice_y_velocity': np.int64(0),
#  'config_environment:constant:land_binary_mask': 'None',
#  'config_environment:fallback:land_binary_mask': 'None',
#  'config_general:use_auto_landmask': 'False',
#  'config_drift:current_uncertainty': np.int64(0),
#  'config_drift:current_uncertainty_uniform': np.int64(0),
#  'config_drift:max_speed': np.int64(1),
#  'config_readers:max_number_of_fails': np.int64(1),
#  'config_general:simulation_name': '',
#  'config_general:coastline_action': 'stranding',
#  'config_general:coastline_approximation_precision': np.float64(0.001),
#  'config_general:time_step_minutes': np.int64(60),
#  'config_general:time_step_output_minutes': 'None',
#  'config_seed:ocean_only': 'True',
#  'config_seed:number': np.int64(1),
#  'config_drift:max_age_seconds': np.float64(1728000.0),
#  'config_drift:advection_scheme': 'euler',
#  'config_drift:profiles_depth': np.int64(50),
#  'config_drift:wind_uncertainty': np.int64(0),
#  'config_drift:relative_wind': 'False',
#  'config_drift:deactivate_north_of': 'None',
#  'config_drift:deactivate_south_of': 'None',
#  'config_drift:deactivate_east_of': 'None',
#  'config_drift:deactivate_west_of': 'None',
#  'config_seed:origin_marker': np.int64(0),
#  'config_seed:z': np.int64(0),
#  'config_seed:sail': np.int64(10),
#  'config_seed:draft': np.int64(90),
#  'config_seed:length': np.int64(100),
#  'config_seed:width': np.int64(30),
#  'config_seed:weight_coef': np.int64(1),
#  'config_seed:water_form_drag_coef': np.float64(0.25),
#  'config_seed:water_skin_drag_coef': np.float64(0.0055),
#  'config_seed:wind_form_drag_coef': np.float64(0.8),
#  'config_seed:wind_skin_drag_coef': np.float64(0.0022),
#  'config_seed:wave_drag_coef': np.float64(0.3),
#  'config_seed:iceb_x_velocity': np.float64(0.0),
#  'config_seed:iceb_y_velocity': np.float64(0.0),
#  'config_drift:wave_rad': 'False',
#  'config_drift:stokes_drift': 'False',
#  'config_drift:coriolis': 'True',
#  'config_drift:sea_surface_slope': 'False',
#  'config_drift:vertical_profile': 'False',
#  'config_processes:grounding': 'True',
#  'config_processes:roll_over': 'True',
#  'config_processes:melting': 'True',
#  'config_melting:wave': 'True',
#  'config_melting:lateral': 'True',
#  'config_melting:basal': 'True',
#  'config_drift:wind_drag': 'True',
#  'config_drift:current_drag': 'True',
#  'config_drift:sea_ice_drag': 'True',
#  'config_drift:sea_ice_lockin': np.float64(0.7),
#  'opendrift_version': '1.14.9',
#  'seed_geojson': '{"features": [], "type": "FeatureCollection"}',
#  'simulation_time': '2026-08-19 11:13:30.551630',
#  'reader_x_sea_water_velocity': "['https://thredds.met.no/thredds/dodsC/cmems/topaz6/dataset-topaz6-arc-15min-3km-be.ncml', 'cmems_mod_arc_phy_my_topaz4_P1D-m']",
#  'reader_y_sea_water_velocity': "['https://thredds.met.no/thredds/dodsC/cmems/topaz6/dataset-topaz6-arc-15min-3km-be.ncml', 'cmems_mod_arc_phy_my_topaz4_P1D-m']",
#  'reader_sea_floor_depth_below_sea_level': "['gebco', 'https://thredds.met.no/thredds/dodsC/cmems/topaz6/dataset-topaz6-arc-15min-3km-be.ncml', 'cmems_mod_arc_phy_my_topaz4_P1D-m']",
#  'reader_sea_surface_height': "['https://thredds.met.no/thredds/dodsC/cmems/topaz6/dataset-topaz6-arc-15min-3km-be.ncml', 'cmems_mod_arc_phy_my_topaz4_P1D-m']",
#  'reader_sea_surface_x_slope': '0',
#  'reader_sea_surface_y_slope': '0',
#  'reader_x_wind': "['cmems_obs-wind_glo_phy_my_l4_0.125deg_PT1H']",
#  'reader_y_wind': "['cmems_obs-wind_glo_phy_my_l4_0.125deg_PT1H']",
#  'reader_horizontal_diffusivity': '0',
#  'reader_sea_surface_wave_significant_height': '0',
#  'reader_sea_surface_wave_from_direction': '0',
#  'reader_sea_surface_wave_stokes_drift_x_velocity': '0',
#  'reader_sea_surface_wave_stokes_drift_y_velocity': '0',
#  'reader_sea_water_temperature': "['cmems_mod_arc_phy_my_topaz4_P1D-m']",
#  'reader_sea_water_salinity': "['cmems_mod_arc_phy_my_topaz4_P1D-m']",
#  'reader_sea_ice_area_fraction': "['cmems_mod_arc_phy_my_topaz4_P1D-m']",
#  'reader_sea_ice_thickness': "['cmems_mod_arc_phy_my_topaz4_P1D-m']",
#  'reader_sea_ice_x_velocity': "['cmems_mod_arc_phy_my_topaz4_P1D-m']",
#  'reader_sea_ice_y_velocity': "['cmems_mod_arc_phy_my_topaz4_P1D-m']",
#  'reader_land_binary_mask': "['gebco']",
#  'time_coverage_end': '2019-05-09 23:00:08',
#  'time_coverage_duration': 'P149DT23H0M0S',
#  'time_coverage_resolution': 'P0DT1H0M0S',
#  'performance': '--------------------\nReader performance:\n--------------------\ngebco\n 0:08:10.8  total\n 0:00:00.3  preparing\n 0:08:09.9  reading\n 0:07:39.4  interpolation\n 0:00:00.6  interpolation_time\n 0:00:00.0  masking\n--------------------\nhttps://thredds.met.no/thredds/dodsC/cmems/topaz6/dataset-topaz6-arc-15min-3km-be.ncml\n 0:40:45.9  total\n 0:00:00.0  preparing\n 0:39:48.0  reading\n 0:00:01.1  interpolation\n 0:00:00.5  interpolation_time\n 0:00:57.5  rotating vectors\n 0:00:00.0  masking\n--------------------\ncmems_mod_arc_phy_my_topaz4_P1D-m\n 0:01:14.6  total\n 0:00:00.1  preparing\n 0:01:14.2  reading\n 0:00:06.9  interpolation\n 0:00:01.7  interpolation_time\n 0:00:00.0  masking\n--------------------\ncmems_obs-wind_glo_phy_my_l4_0.125deg_PT1H\n 0:04:15.5  total\n 0:00:00.0  preparing\n 0:04:15.2  reading\n 0:00:01.0  interpolation\n 0:00:00.3  interpolation_time\n 0:00:00.0  masking\n--------------------\nPerformance:\n57:12.3 total time\n    0.0 configuration\n   17.4 preparing main loop\n     17.4 moving elements to ocean\n56:54.7 main loop\n     32.5 updating elements\n    0.0 cleaning up\n--------------------\n',
#  'geospatial_bounds_crs': 'EPSG:4326',
#  'geospatial_bounds_vertical_crs': 'EPSG:5831',
#  'geospatial_lat_min': np.float32(nan),
#  'geospatial_lat_max': np.float32(nan),
#  'geospatial_lat_units': 'degrees_north',
#  'geospatial_lat_resolution': 'point',
#  'geospatial_lon_min': np.float32(nan),
#  'geospatial_lon_max': np.float32(nan),
#  'geospatial_lon_units': 'degrees_east',
#  'geospatial_lon_resolution': 'point',
#  'runtime': '0:57:12.344304',
#  'geospatial_vertical_min': np.float32(nan),
#  'geospatial_vertical_max': np.float32(nan),
#  'geospatial_vertical_positive': 'up'}

# %%
sim.y_sea_water_velocity.plot()

# %%
# # --- Open all simulation results in one dataset --- 
# with xr.open_mfdataset(
#     file_l,
#     combine="nested",
#     concat_dim="run",
#     parallel=True,
#     engine="netcdf4",
#     # chunks={'time': 10}
# ) as simall: 
#     simall = simall.assign_coords(run=file_l)  # or any list of labels

# %%
# # --- find trajectories
# # by seeding length
# seedinglengths = np.nanmax(simall.length[0,:,:],axis=1)
# seedinglengths_unq = np.unique(seedinglengths)
# print(seedinglengths_unq)
# seedinglengths_dict = {v: np.where(seedinglengths == v)[0].tolist() for v in seedinglengths_unq}
# trajs = np.array([seedinglengths_dict[sl] for sl in seedinglengths_unq[2:]]).flatten()

# #by time
# trajs = np.arange(0,10*10+1) #PART1
# print(trajs, simall.sel(trajectory=trajs).time[np.array([0,-1])].values, np.unique(seedinglengths[trajs]))
# traj = False
# # note = 'wave_only_o300length'

# %%
# runtrajdict = {#for analysis of part I and II [timestep: 0-10,11-19]
#              'nextsimanfc_glophyanfc_waverys_windglophynrt':np.arange(0,26*10),
#              'nextsimanfc_glophyanfc_mfwam_windglophynrt':np.arange(0,20*10),
#              'nextsimanfc_glophyanfc_arcmfcwam_windglophynrt':np.arange(0,20*10),
#              'nextsimanfc_topaz5_waverys_windglophynrt':np.arange(0,20*10),
#              'nextsimanfc_topaz5_mfwam_windglophynrt':np.arange(0,20*10),
#              'nextsimanfc_topaz5_arcmfcwam_windglophynrt':np.arange(0,20*10),
#              'nextsimanfc_topaz6_topaz5_waverys_windglophynrt':np.arange(0,20*10),
#              'nextsimanfc_topaz6_topaz5_mfwam_windglophynrt':np.arange(0,20*10),
#              'nextsimanfc_topaz6_topaz5_arcmfcwam_windglophynrt':np.arange(0,20*10),
#             #for analysis of part III
#               # 'nextsimanfc_glophyanfc_arcmfcwam_windglophynrt':np.arange(20*10,26*10), #2nd
#              'glophyanfc_waverys_windglophynrt':np.arange(20*10,26*10),
#              'topaz5_waverys_windglophynrt':np.arange(20*10,26*10),
#              'topaz6_topaz5_waverys_windglophynrt':np.arange(20*10,26*10),#maybe change ideces here to matchdifferent counting
#             'nextsim':np.arange(20*10,26*10),
# }
# colordict = {#for analysis of part I and II
#              'nextsimanfc_glophyanfc_waverys_windglophynrt':{'col':'orange','alpha':1,'kw':'Glophyanfc'},
#              'nextsimanfc_glophyanfc_mfwam_windglophynrt':{'col':'orange','alpha':0.7,'kw':'Glophyanfc'},
#              'nextsimanfc_glophyanfc_arcmfcwam_windglophynrt':{'col':'orange','alpha':0.4,'kw':'Glophyanfc'},
#              'nextsimanfc_topaz5_waverys_windglophynrt':{'col':'cyan','alpha':1,'kw':'TOPAZ5'},
#              'nextsimanfc_topaz5_mfwam_windglophynrt':{'col':'cyan','alpha':0.7,'kw':'TOPAZ5'},
#              'nextsimanfc_topaz5_arcmfcwam_windglophynrt':{'col':'cyan','alpha':0.4,'kw':'TOPAZ5'},
#              'nextsimanfc_topaz6_topaz5_waverys_windglophynrt':{'col':'green','alpha':1,'kw':'TOPAZ6+5'},
#              'nextsimanfc_topaz6_topaz5_mfwam_windglophynrt':{'col':'green','alpha':0.7,'kw':'TOPAZ6+5'},
#              'nextsimanfc_topaz6_topaz5_arcmfcwam_windglophynrt':{'col':'green','alpha':0.4,'kw':'TOPAZ6+5'},
#             #for analysis of part III
#              'nextsim':{'col':'red','alpha':1,'kw':'neXtSIM'},
#              'glophyanfc_waverys_windglophynrt':{'col':'orange','alpha':1,'kw':'Glophyanfc'},
#              'topaz5_waverys_windglophynrt':{'col':'cyan','alpha':1,'kw':'TOPAZ5'},
#              'topaz6_topaz5_waverys_windglophynrt':{'col':'green','alpha':1,'kw':'TOPAZ6+5'},
# }
# legenddict = {              
#             'Simulations with input by: \nneXtSIM':{'col':'red','alpha':1},
#             'Glophyanfc':{'col':'orange','alpha':1},
#               'TOPAZ5':{'col':'cyan','alpha':1},
#               'TOPAZ6+5':{'col':'green','alpha':1},
#               'WAVERYS (alpha=1)':{'col':'green','alpha':1},
#               'MFWAM (alpha=0.7)':{'col':'green','alpha':0.7},
#               'ARCMFCWAM (alpha=0.4)':{'col':'green','alpha':0.4},
#              }

# %%
# # Map plot comparing simulations with different input

# #def
# url_letters, note_letters, fileending_letters = 19,8,3
# note = 'all'
# #by = inputdataidx
# # cmap = plt.get_cmap('tab20')  # or 'viridis', 'plasma', etc.
# # col = cmap(np.linspace(0, 1, 20))[::2]#20 colors


# #Figure
# fig,ax = plt.subplots(1,1,figsize=(10,10),subplot_kw={'projection':ccrs.NorthPolarStereo()})#central_longitude=20})
# ax.coastlines(resolution='10m')
# trans = ccrs.PlateCarree()
# #ax.set_extent((-42.5, -11, 65, 78))

# # plot sim
# #version that reads from join simall datset
# # for inputdataidx, inputdataurl in enumerate(simall.run.values):
# #     inputdata = inputdataurl[url_letters:-(note_letters+fileending_letters)]
# #     print(inputdataidx, inputdata,colordict[inputdata])
#     # for traj in runtrajdict[inputdata]:# trajs if traj else simall.trajectory:
#     #     plotcol = colordict['nextsim']['col'] if np.logical_and(inputdata=='nextsimanfc_glophyanfc_waverys_windglophynrt',traj in np.arange(10*20,26*10,1)) else colordict[inputdata]['col']
#     #     ax.plot(simall.lon.sel(run=inputdataurl,trajectory=traj).dropna(dim="time"),simall.lat.sel(run=inputdataurl,trajectory=traj).dropna(dim="time"),
#     #     color= plotcol,
#     #     alpha=colordict[inputdata]['alpha'],#col[inputdataidx],
#     #     linewidth=0.5,
#     #     transform=trans)
#     #version that open up every sim results individually (faster)
# for inputdataidx, inputdata in enumerate(file_l):
#     sim = xr.open_dataset('./results/juliette_%s_wavedir.nc'%(inputdata if inputdata!='nextsim' else 'nextsimanfc_glophyanfc_waverys_windglophynrt'))
#     plot_col = colordict[inputdata]['col']
#     print(inputdataidx, inputdata ,colordict[inputdata])
#     for traj in runtrajdict[inputdata]:
#         # plotcol = colordict['nextsim']['col'] if np.logical_and(inputdata=='nextsimanfc_glophyanfc_waverys_windglophynrt',traj in np.arange(10*20,26*10,1)) else colordict[inputdata]['col']
#         ax.plot(sim.lon.sel(trajectory=traj).dropna(dim="time"),sim.lat.sel(trajectory=traj).dropna(dim="time"),
#             color= plot_col,
#             alpha=colordict[inputdata]['alpha'],#col[inputdataidx],
#             linewidth=0.5,
#             transform=trans)

# # plot obs
# ax.plot(obs_3day['lon'],obs_3day['lat'],'>',transform=trans,color='k')
# ax.plot(obs['lon'],obs['lat'],transform=trans,color='k',label='Observation')
# # for d in range(obs_3day['time'].size):
# for d in range(obs_3day.time.size):
#     if d not in [1,2,3,4,5,12,15,16,17,18,19]:
#         ax.text(obs_3day['lon'][d],obs_3day['lat'][d],obs_3day['time'][d].values.astype('datetime64[D]').astype(str),transform=trans,color='k',fontsize=12)

# #legend
# legend_elements = [Line2D([0], [0],linestyle='-', color='k', lw=1,label='Observations'),
#                   Line2D([0], [0],linestyle='-', color='w',marker='>',markerfacecolor='k', lw=1,label='3-daily Positions')]
# # legend_elements = legend_elements+[Line2D([0], [0],linestyle='-', color=col[inputdataidx2], lw=1,
# #                                           label=inputdata2[url_letters:-(note_letters+fileending_letters)].replace('_',', ').title() if inputdataidx2>0 else 'Simulations with input by: \n'+inputdata2[19:-3].replace('_',', ').title() )
# #                                           for inputdataidx2,inputdata2 in enumerate(simall.run.values)]
# legend_elements = legend_elements+[Line2D([0], [0],linestyle='-', color=legenddict[el]['col'],alpha=legenddict[el]['alpha'], lw=1, label=el) for el in legenddict]
# leg = fig.legend(handles=legend_elements,bbox_to_anchor=(0.15, 0.34),loc='upper left',fontsize=13)#fontsize=fs,ncol=len(legend_elements0+legend_elements2),                  columnspacing=0.6,labelspacing=0.3,loc='center',bbox_to_anchor=bbox_dict[kw][0])
# plt.axis('off')
# fig.add_artist(leg)
# if note!=False: plt.savefig('./results/analysis_juliette_map_%s.png'%note,dpi=200,transparent=True,bbox_inches='tight')
# plt.show()

# %%
# --- Checks on combined dataset of simulations results simall

# # --Check for variables from one "seeding round"
# # simall.length[0,np.arange(60,70),:].dropna(dim='time').shape 

# # --Check for variables at datetime
# simall_t1 = simall.sel(time=datetime(2025,10,18,0), method="nearest") 

# simall_t1_nan = simall_t1.dropna(
#     dim="trajectory",
#     # subset=["sea_surface_wave_from_direction"],
#     subset=["length"],
#     how="any" )
# # print(simall_t1_nan.run) #which runs
# #print (simall_t1_nan.trajectory) #which trajectory numbers
# # simall_t1_nan.sea_surface_wave_from_direction.values
# # simall_t1_nan.sea_surface_wave_significant_height.values
# # simall_t1_nan.sea_surface_wave_stokes_drift_x_velocity.plot()
# # simall_t1_nan.x_sea_water_velocity.values
# simall_t1_nan.sea_ice_area_fraction.plot()

# # simall_t1_nan.draft.values#[:,0].values

# %%
# --- Checks on one simulation result file ---

# sim = xr.open_dataset('./results/juliette_topaz6_topaz5_waverys_windglophynrt_wavedir.nc')
# np.sum(np.isnan(sim.x_sea_water_velocity))/sim.x_sea_water_velocity.size
# sim_t1 = sim.sel(time=datetime(2025,10,21,0), method="nearest") 
# sim_t1.sea_surface_wave_from_direction.plot()
# sim.x_sea_water_velocity.plot()
# sim.attrs
